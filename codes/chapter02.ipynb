# %%
professor = "Seunghoon Yang"
print(professor)
# Out:
# Seunghoon Yang

# %%
print("Hello, world")
# Out:
# Hello, world

# %% [markdown]
# # Chapter 2. 변수와 자료형
#
# ## 1. 변수의 이해

# %%
professor = "SH Yang"
print(professor)
# Out:
# SH Yang

# %%
a = 7
b = 5
print(a + b)
# Out:
# 12

# %%
a = 7
b = 5
print("a + b")
# Out:
# a + b

# %% [markdown]
# ## 2. 자료형과 기본 연산

# %%
a = 1
b = 1
print(a, b)
# Out:
# 1 1

# %%
a = 1.5
b = 3.5
print(a, b)
# Out:
# 1.5 3.5

# %%
a = "ABC"
b = "101010"
print(a, b)
# Out:
# ABC 101010

# %%
a = True
b = False 
print(a, b)
# Out:
# True False

# %%
25 + 30
# Out:
# 55

# %%
30 - 12
# Out:
# 18

# %%
50 * 3
# Out:
# 150

# %%
30 / 5
# Out:
# 6.0

# %%
print(3 * 3 * 3 * 3 * 3)
# Out:
# 243

# %%
print(3**5)
# Out:
# 243

# %%
print(7 // 2)
# Out:
# 3

# %%
print(7 % 2)
# Out:
# 1

# %%
a = 1
a = a + 1

# %%
print(a)
# Out:
# 2

# %%
a += 1
print(a)
# Out:
# 3

# %%
a = a - 1
a -= -1
print(a)
# Out:
# 3

# %% [markdown]
# ## 3. 자료형 변환

# %%
a = 10
print(a)
# Out:
# 10

# %%
a = float(10)
print(a)
# Out:
# 10.0

# %%
a = 10
b = 3
print(a / b)
# Out:
# 3.3333333333333335

# %%
a = int(10.7)
b = int(10.3)

# %%
print(a + b)
# Out:
# 20

# %%
print(a, b)
# Out:
# 10 10

# %%
a = '76.3'
b = float(a)

# %%
print(a, b)
# Out:
# 76.3 76.3

# %%
### print(a + b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(a + b)
#
# TypeError: can only concatenate str (not "float") to str

# %%
a = float(a)
b = a
print(a + b)
# Out:
# 152.6

# %%
a = str(a)
b = str(b)
print(a + b)
# Out:
# 76.376.3

# %%
a = int(10.3)
b = float(10.3)
c = str(10.3)

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
a = 20
b = '10'

# %%
print(a <= b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 print(a <= b)
#
# TypeError: '<=' not supported between instances of 'int' and 'str'

# %%
print(a != int(b))
# Out:
# True

# %%
print(str(a) != b)
# Out:
# True

# %%
print(a is not int(b))
# Out:
# True

# %%
print(int(a) >= int(b))
# Out:
# True

# %%
a = "1.5"
b = 4

# %%
print(a * b)
# Out:
# 1.51.51.51.5

# %%
a = "10"; b = "40"
