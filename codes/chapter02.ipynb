# %%
professor = "Seunghoon Yang"
print(professor)
# Out:
# Seunghoon Yang

# %%
print("Hello, world")
# Out:
# Hello, world

# %% [markdown]
# # Chapter 2. 변수와 자료형
#
# ## 1. 변수의 이해

# %%
professor = "SH Yang"
print(professor)
# Out:
# SH Yang

# %%
a = 7
b = 5
print(a + b)
# Out:
# 12

# %%
a = 7
b = 5
print("a + b")
# Out:
# a + b
